# %% [markdown]
# ## Linear Regression
# #### Multivariant Linear Regression, from scratch.

# %% [markdown]
# #### AI Saturday Lagos Begineers Class (Instructors: `Tejumade Afonja`, `Kenechi Dukor`, `Stanley Dukor`, `Kelechi`)
# This exercise is adopted from [Andrew Ng Machine Learning Course](https://www.coursera.org/learn/machine-learning)

# %%
# Libraries required for this practice 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Data

# %% [markdown]
# The data we will be using is a .txt file which contains a list of bedroom sizes, number of bedrooms and their corresponding price of the house.
#
# The values on the first column contains the bedroom sizes, the values of the second column contains the number of bedrooms and values on the third column contains the corresponding price of the house, in Naira.
#
# The goal of this exercise is to use linear regression and the optimization technique to generate a model that will predcit reasonable estimate of a house price when it is supplied the customers desired room size and number of rooms.

# %%
# Using pandas to view the data
data = pd.read_csv('data/ex1data2.txt', names=['size','bedroom','price'])
data.head() # this will show the first five data in the dataframe
# Out:
#    size  bedroom   price
# 0  2104        3  399900
# 1  1600        3  329900
# 2  2400        3  369000
# 3  1416        2  232000
# 4  3000        4  539900

# %%
# Lets convert values of the pandas dataframe into a numpy array
data = data.values

# %% [markdown]
# You can also convert the data in to a numpy array without needing to go through pandas. Use the code below
#
# `data = np.loadtxt("ex1data1.txt", delimiter=',')`

# %%
data.shape
# Out:
# (47, 3)

# %% [markdown]
# We have 47 training examples and two independent variable `x` on the first and second column and one dependent variable `y` on the third column
#
# **Recall:**
# - Our untrained model is given by: ![title](img/model.gif)
#
# - Which you can also be written as ![title](img/model2.gif)
#
# where:
# - `y` is the ground truth or output
# - `x` is the input values
# - `theta` is the weight or parameters that needs to learn

# %% [markdown]
# Beacuse we have three coefficient of `theta` `( x1, x2)`, we want to create a `97 x 2` matrix that contains the input values on the first column and second column.
#
# Notice that unlike in the last class, we did not create a third column here that contains `ones` which are coefficients for the **bias** `ie (theta0)`. This is because we would still have to normalize the input data. and it makes no sense normalizing `ones`, because we want them to remain as `ones`.

# %%
x_data = np.c_[data[:,0], data[:,1]]

# %% [markdown]
# Similarly, we want to create a row vector with a dimension of `97 x 1` for all the output values in our dataset

# %%
y = np.c_[data[:,2]]
y.shape
# Out:
# (47, 1)

# %% [markdown]
# ### Data Visualization

# %%
# Lets plot the data to see how they correlate.
plt.scatter(x_data[:,0], y, s=32, marker='o')
plt.xlabel("Room Size")
plt.ylabel("Price")
plt.title("ROOM SIZE VS PRICE")
# Out:
# Text(0.5, 1.0, 'ROOM SIZE VS PRICE')

# %%
plt.scatter(x_data[:,1], y, s=32, marker='x')
plt.xlabel("Number of Bedroom")
plt.ylabel("Price")
plt.title("NUMBER OF ROOMS VS PRICE")
# Out:
# Text(0.5, 1.0, 'NUMBER OF ROOMS VS PRICE')

# %% [markdown]
# ### Class Discussion
#
# - What do you notice from the two plots?
# - Do you thing a reasonable model can be created?

# %% [markdown]
# ### Quick refresher
#
# Lets plot a 3D representation on the data for you to observe

# %%
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 

# our input data

x1 = x_data[:,0]
x2 = x_data[:,1]

c = (x2<=0)
fig = plt.figure()
ax = Axes3D(fig) 

ax.scatter3D(x1, y, x2, c=c, cmap="coolwarm" );

# %% [markdown]
# **Class Discussion:** What do you understand from the plot?? lol

# %% [markdown]
# ## Feature Normalizing

# %% [markdown]
# Since the range of values of raw data varies widely, in some machine learning algorithms, objective functions will not work properly without normalization. ... Therefore, the range of all features should be normalized so that each feature contributes approximately proportionately to the final distance. [wiki](https://en.wikipedia.org/wiki/Feature_scaling)
# In this notebook, we will normalize our data using the formula below
# ![title](img/eqn1.gif)

# %%
def featureNorm(x_data):
    # save the feature data in another variable
    x_norm = x_data.copy()
    
    # Create a row vector of zeros, having the same number of rows as the input feature
    mean = np.mean(x_data, axis=0)
    standard_deviation = np.std(x_data, axis=0)
    print("... The mean and standard devation for the room sizes are: ", mean[0], " and ", standard_deviation[0] , "\n")
    print("... The mean and standard devation for the number of rooms are: ", mean[1], " and ", standard_deviation[1], "\n")
    
    # The formula
    x_norm = np.divide((x_data - mean),standard_deviation)
    print("... Input feature has been normalized", "\n")
    
    # Now, we can add the one vector that represent the coefficent of the bias that we discussed earlier
    x = np.concatenate((np.ones((x_data[:,0].size, 1)), x_norm), axis=1) 
    print("... A ones vector has been successfully concatenated to the input feature matrix", "\n")
    
    return x, mean, standard_deviation

# %%
x, mean, standard_deviation = featureNorm(x_data)
# Out:
# ... The mean and standard devation for the room sizes are:  2000.6808510638298  and  786.2026187430467
#
# ... The mean and standard devation for the number of rooms are:  3.1702127659574466  and  0.7528428090618782
#
# ... Input feature has been normalized
#
# ... A ones vector has been successfully concatenated to the input feature matrix

# %% [markdown]
# ### Training

# %% [markdown]
# Recall from the class, the process to training a linear regression model is as follow.
#
# We want to find the appropriate value of `theta` that will give us a good estimate of a city's profit if lthe city's population is supplied.
#
# To do this,
# - We want to start with a random value of `theta` to generate a hypothesis
# ![title](img/model3.gif)
#
# - Then continually correct values of `theta` until the deviation of the hypothesis/prediction `h` from the ground-truth `y` is greatly reduced
#
# **Note:** In the last class, we used something like this `theta = [[0],[0],[0]]` to initialize the values of theta. Going forward, we will use the numpy function to initialize the values of theta, because we could have large number of theta values. ie `theta = np.zeros(3)`

# %%
def train(x, y):
    iteration = 1000
    # For this practice are initiallizing are theta with values of zero.
    theta = np.zeros((3, 1))
    
    # Here, want to save our cost function or loss or square error, 
    # so that we can have an idea of how the deviation of the hypothesis from the ground thruth reduces
    cost_function = np.zeros(iteration)
    
    for i in range(iteration):
        # Step 1: we make a prediction using the random weights (theta) that we initialized
        # @ is a fancy way do performing dot products
        h = x @ theta
        # Step 2: We take a step to correct the weights (theta) to that the next predicion will be better
        theta = update_weight(h, theta, x)
        # Step 3: We measure the deviation or error
        cost_function[i] = cost(x, theta)

        print("Running Gradient Descent. Current cost function is ", np.log(cost_function[i]))
        
    return theta, cost_function

# %% [markdown]
# But how do we check the error like we defined above?
#
# Remember the error formular (cost function)?
# ![title](img/model44.gif)
#
# where:
# - `m` is the number of training example
# - `x` is the input data
# - `h` is the hypothesis
# - `y` is the prediction
#
# The equation tries to find the square error between the ground truth and the prediction.

# %%
def cost(x, theta):
    m = x[:,0].size
    h = x @ theta
    return (1/2*m) * np.sum(np.square(h - y))

# %% [markdown]
# Now that we are able to get a sense of the error, how do we update how weight (theta) such that is predicts better?
#
# Like we discussed in class, gradient descent algorithim will be used for this purpose.
#
# The general formular for gradient is given below:
# ![title](img/model6.gif)
# which can be differentiated to give:
# ![title](img/model5.gif)
# where
# - alpha is the learning rate
#
# ie: we continually update the weight(theta) by taking steps(alpha) for the derived gradient of the error until we have sufficiently minimized theta.

# %%
def update_weight(h, theta, x):
    m = x[:,0].size
    alpha = 0.01
    theta = theta - alpha * (1/m * (x.T @ (h - y)))
    return theta

# %% [markdown]
# Now, lets pass in our data and train.

# %%
theta, cost_values = train(x, y)
# Out:
# Running Gradient Descent. Current cost function is  32.58708608705592
# Running Gradient Descent. Current cost function is  32.567187999647466
# Running Gradient Descent. Current cost function is  32.54731381481136
# Running Gradient Descent. Current cost function is  32.52746372620842
# Running Gradient Descent. Current cost function is  32.50763793234512
# Running Gradient Descent. Current cost function is  32.48783663661972
# Running Gradient Descent. Current cost function is  32.468060047368105
# Running Gradient Descent. Current cost function is  32.44830837790955
# Running Gradient Descent. Current cost function is  32.42858184659219
# Running Gradient Descent. Current cost function is  32.408880676838244
# Running Gradient Descent. Current cost function is  32.38920509718902
# Running Gradient Descent. Current cost function is  32.36955534134949
# Running Gradient Descent. Current cost function is  32.349931648232534
# Running Gradient Descent. Current cost function is  32.33033426200286
# Running Gradient Descent. Current cost function is  32.3107634321203
# Running Gradient Descent. Current cost function is  32.29121941338282
# Running Gradient Descent. Current cost function is  32.271702465968836
# Running Gradient Descent. Current cost function is  32.252212855479016
# Running Gradient Descent. Current cost function is  32.23275085297743
# Running Gradient Descent. Current cost function is  32.21331673503207
# Running Gradient Descent. Current cost function is  32.19391078375457
# Running Gradient Descent. Current cost function is  32.17453328683915
# Running Gradient Descent. Current cost function is  32.15518453760081
# Running Gradient Descent. Current cost function is  32.1358648350125
# Running Gradient Descent. Current cost function is  32.11657448374142
# Running Gradient Descent. Current cost function is  32.09731379418431
# Running Gradient Descent. Current cost function is  32.078083082501614
# Running Gradient Descent. Current cost function is  32.05888267065055
# Running Gradient Descent. Current cost function is  32.03971288641694
# Running Gradient Descent. Current cost function is  32.02057406344584
# Running Gradient Descent. Current cost function is  32.00146654127074
# Running Gradient Descent. Current cost function is  31.982390665341388
# Running Gradient Descent. Current cost function is  31.963346787050202
# Running Gradient Descent. Current cost function is  31.944335263757022
# Running Gradient Descent. Current cost function is  31.925356458812285
# Running Gradient Descent. Current cost function is  31.906410741578497
# Running Gradient Descent. Current cost function is  31.887498487449886
# Running Gradient Descent. Current cost function is  31.868620077870226
# Running Gradient Descent. Current cost function is  31.84977590034867
# Running Gradient Descent. Current cost function is  31.83096634847358
# Running Gradient Descent. Current cost function is  31.812191821924205
# Running Gradient Descent. Current cost function is  31.79345272648019
# Running Gradient Descent. Current cost function is  31.77474947402875
# Running Gradient Descent. Current cost function is  31.75608248256947
# Running Gradient Descent. Current cost function is  31.737452176216635
# Running Gradient Descent. Current cost function is  31.718858985198974
# Running Gradient Descent. Current cost function is  31.70030334585674
# Running Gradient Descent. Current cost function is  31.681785700636027
# Running Gradient Descent. Current cost function is  31.663306498080228
# Running Gradient Descent. Current cost function is  31.644866192818547
# Running Gradient Descent. Current cost function is  31.62646524555142
# Running Gradient Descent. Current cost function is  31.60810412303282
# Running Gradient Descent. Current cost function is  31.589783298049277
# Running Gradient Descent. Current cost function is  31.571503249395555
# Running Gradient Descent. Current cost function is  31.55326446184686
# Running Gradient Descent. Current cost function is  31.53506742612749
# Running Gradient Descent. Current cost function is  31.51691263887582
# Running Gradient Descent. Current cost function is  31.498800602605506
# Running Gradient Descent. Current cost function is  31.480731825662854
# Running Gradient Descent. Current cost function is  31.46270682218018
# Running Gradient Descent. Current cost function is  31.44472611202511
# Running Gradient Descent. Current cost function is  31.426790220745694
# Running Gradient Descent. Current cost function is  31.408899679511276
# Running Gradient Descent. Current cost function is  31.391055025048924
# Running Gradient Descent. Current cost function is  31.373256799575447
# Running Gradient Descent. Current cost function is  31.355505550724796
# Running Gradient Descent. Current cost function is  31.337801831470806
# Running Gradient Descent. Current cost function is  31.32014620004517
# Running Gradient Descent. Current cost function is  31.302539219850548
# Running Gradient Descent. Current cost function is  31.28498145936874
# Running Gradient Descent. Current cost function is  31.267473492063797
# Running Gradient Descent. Current cost function is  31.250015896280015
# Running Gradient Descent. Current cost function is  31.232609255134733
# Running Gradient Descent. Current cost function is  31.215254156405816
# Running Gradient Descent. Current cost function is  31.19795119241379
# Running Gradient Descent. Current cost function is  31.180700959898527
# Running Gradient Descent. Current cost function is  31.163504059890432
# Running Gradient Descent. Current cost function is  31.146361097576033
# Running Gradient Descent. Current cost function is  31.12927268215797
# Running Gradient Descent. Current cost function is  31.112239426709248
# Running Gradient Descent. Current cost function is  31.095261948021793
# Running Gradient Descent. Current cost function is  31.078340866449174
# Running Gradient Descent. Current cost function is  31.061476805743542
# Running Gradient Descent. Current cost function is  31.04467039288667
# Running Gradient Descent. Current cost function is  31.027922257915108
# Running Gradient Descent. Current cost function is  31.01123303373945
# Running Gradient Descent. Current cost function is  30.994603355957643
# Running Gradient Descent. Current cost function is  30.978033862662375
# Running Gradient Descent. Current cost function is  30.96152519424253
# Running Gradient Descent. Current cost function is  30.945077993178693
# Running Gradient Descent. Current cost function is  30.928692903832786
# Running Gradient Descent. Current cost function is  30.91237057223177
# Running Gradient Descent. Current cost function is  30.896111645845508
# Running Gradient Descent. Current cost function is  30.879916773358822
# Running Gradient Descent. Current cost function is  30.86378660443777
# Running Gradient Descent. Current cost function is  30.8477217894902
# Running Gradient Descent. Current cost function is  30.831722979420725
# Running Gradient Descent. Current cost function is  30.815790825380052
# Running Gradient Descent. Current cost function is  30.79992597850891
# Running Gradient Descent. Current cost function is  30.784129089676586
# Running Gradient Descent. Current cost function is  30.768400809214164
# Running Gradient Descent. Current cost function is  30.752741786642666
# Running Gradient Descent. Current cost function is  30.73715267039615
# Running Gradient Descent. Current cost function is  30.721634107539938
# Running Gradient Descent. Current cost function is  30.706186743484132
# Running Gradient Descent. Current cost function is  30.690811221692545
# Running Gradient Descent. Current cost function is  30.675508183387276
# Running Gradient Descent. Current cost function is  30.660278267249062
# Running Gradient Descent. Current cost function is  30.64512210911363
# Running Gradient Descent. Current cost function is  30.630040341664238
# Running Gradient Descent. Current cost function is  30.61503359412066
# Running Gradient Descent. Current cost function is  30.600102491924797
# Running Gradient Descent. Current cost function is  30.585247656423157
# Running Gradient Descent. Current cost function is  30.57046970454651
# Running Gradient Descent. Current cost function is  30.555769248486914
# Running Gradient Descent. Current cost function is  30.5411468953724
# Running Gradient Descent. Current cost function is  30.526603246939626
# Running Gradient Descent. Current cost function is  30.512138899204757
# Running Gradient Descent. Current cost function is  30.497754442132887
# Running Gradient Descent. Current cost function is  30.4834504593063
# Running Gradient Descent. Current cost function is  30.469227527591908
# Running Gradient Descent. Current cost function is  30.455086216808176
# Running Gradient Descent. Current cost function is  30.44102708939189
# Running Gradient Descent. Current cost function is  30.427050700065063
# Running Gradient Descent. Current cost function is  30.413157595502405
# Running Gradient Descent. Current cost function is  30.39934831399962
# Running Gradient Descent. Current cost function is  30.385623385143003
# Running Gradient Descent. Current cost function is  30.371983329480575
# Running Gradient Descent. Current cost function is  30.35842865819526
# Running Gradient Descent. Current cost function is  30.34495987278038
# Running Gradient Descent. Current cost function is  30.3315774647179
# Running Gradient Descent. Current cost function is  30.318281915159805
# Running Gradient Descent. Current cost function is  30.305073694612958
# Running Gradient Descent. Current cost function is  30.291953262627867
# Running Gradient Descent. Current cost function is  30.278921067491755
# Running Gradient Descent. Current cost function is  30.265977545926248
# Running Gradient Descent. Current cost function is  30.253123122790168
# Running Gradient Descent. Current cost function is  30.240358210787758
# Running Gradient Descent. Current cost function is  30.227683210182697
# Running Gradient Descent. Current cost function is  30.21509850851837
# Running Gradient Descent. Current cost function is  30.202604480344682
# Running Gradient Descent. Current cost function is  30.190201486951846
# Running Gradient Descent. Current cost function is  30.177889876111454
# Running Gradient Descent. Current cost function is  30.16566998182527
# Running Gradient Descent. Current cost function is  30.153542124081998
# Running Gradient Descent. Current cost function is  30.141506608622443
# Running Gradient Descent. Current cost function is  30.12956372671338
# Running Gradient Descent. Current cost function is  30.117713754930406
# Running Gradient Descent. Current cost function is  30.105956954950198
# Running Gradient Descent. Current cost function is  30.09429357335233
# Running Gradient Descent. Current cost function is  30.08272384143107
# Running Gradient Descent. Current cost function is  30.07124797501736
# Running Gradient Descent. Current cost function is  30.059866174311292
# Running Gradient Descent. Current cost function is  30.048578623725238
# Running Gradient Descent. Current cost function is  30.03738549173799
# Running Gradient Descent. Current cost function is  30.02628693076004
# Running Gradient Descent. Current cost function is  30.01528307701024
# Running Gradient Descent. Current cost function is  30.00437405040398
# Running Gradient Descent. Current cost function is  29.99355995445317
# Running Gradient Descent. Current cost function is  29.982840876177995
# Running Gradient Descent. Current cost function is  29.97221688603076
# Running Gradient Descent. Current cost function is  29.961688037831824
# Running Gradient Descent. Current cost function is  29.95125436871774
# Running Gradient Descent. Current cost function is  29.94091589910172
# Running Gradient Descent. Current cost function is  29.930672632646445
# Running Gradient Descent. Current cost function is  29.92052455624925
# Running Gradient Descent. Current cost function is  29.91047164003976
# Running Gradient Descent. Current cost function is  29.9005138373899
# Running Gradient Descent. Current cost function is  29.89065108493635
# Running Gradient Descent. Current cost function is  29.880883302615302
# Running Gradient Descent. Current cost function is  29.871210393709568
# Running Gradient Descent. Current cost function is  29.86163224490788
# Running Gradient Descent. Current cost function is  29.852148726376345
# Running Gradient Descent. Current cost function is  29.84275969184189
# Running Gradient Descent. Current cost function is  29.833464978687626
# Running Gradient Descent. Current cost function is  29.82426440805991
# Running Gradient Descent. Current cost function is  29.815157784987004
# Running Gradient Descent. Current cost function is  29.806144898509107
# Running Gradient Descent. Current cost function is  29.797225521819556
# Running Gradient Descent. Current cost function is  29.78839941241702
# Running Gradient Descent. Current cost function is  29.77966631226841
# Running Gradient Descent. Current cost function is  29.771025947982274
# Running Gradient Descent. Current cost function is  29.76247803099241
# Running Gradient Descent. Current cost function is  29.754022257751444
# Running Gradient Descent. Current cost function is  29.74565830993406
# Running Gradient Descent. Current cost function is  29.737385854649578
# Running Gradient Descent. Current cost function is  29.72920454466359
# Running Gradient Descent. Current cost function is  29.72111401862832
# Running Gradient Descent. Current cost function is  29.71311390132138
# Running Gradient Descent. Current cost function is  29.705203803892534
# Running Gradient Descent. Current cost function is  29.69738332411824
# Running Gradient Descent. Current cost function is  29.689652046663454
# Running Gradient Descent. Current cost function is  29.682009543350457
# Running Gradient Descent. Current cost function is  29.67445537343427
# Running Gradient Descent. Current cost function is  29.66698908388431
# Running Gradient Descent. Current cost function is  29.659610209671893
# Running Gradient Descent. Current cost function is  29.652318274063198
# Running Gradient Descent. Current cost function is  29.645112788917334
# Running Gradient Descent. Current cost function is  29.63799325498909
# Running Gradient Descent. Current cost function is  29.63095916223599
# Running Gradient Descent. Current cost function is  29.624009990129288
# Running Gradient Descent. Current cost function is  29.61714520796847
# Running Gradient Descent. Current cost function is  29.61036427519893
# Running Gradient Descent. Current cost function is  29.603666641732392
# Running Gradient Descent. Current cost function is  29.597051748269724
# Running Gradient Descent. Current cost function is  29.590519026625742
# Running Gradient Descent. Current cost function is  29.584067900055683
# Running Gradient Descent. Current cost function is  29.57769778358288
# Running Gradient Descent. Current cost function is  29.571408084327416
# Running Gradient Descent. Current cost function is  29.565198201835244
# Running Gradient Descent. Current cost function is  29.559067528407557
# Running Gradient Descent. Current cost function is  29.553015449429985
# Running Gradient Descent. Current cost function is  29.547041343701306
# Running Gradient Descent. Current cost function is  29.541144583761348
# Running Gradient Descent. Current cost function is  29.535324536217765
# Running Gradient Descent. Current cost function is  29.52958056207135
# Running Gradient Descent. Current cost function is  29.52391201703963
# Running Gradient Descent. Current cost function is  29.518318251878412
# Running Gradient Descent. Current cost function is  29.51279861270101
# Running Gradient Descent. Current cost function is  29.50735244129488
# Running Gradient Descent. Current cost function is  29.501979075435436
# Running Gradient Descent. Current cost function is  29.49667784919671
# Running Gradient Descent. Current cost function is  29.491448093258725
# Running Gradient Descent. Current cost function is  29.48628913521126
# Running Gradient Descent. Current cost function is  29.481200299853846
# Running Gradient Descent. Current cost function is  29.476180909491767
# Running Gradient Descent. Current cost function is  29.471230284227836
# Running Gradient Descent. Current cost function is  29.466347742249845
# Running Gradient Descent. Current cost function is  29.461532600113415
# Running Gradient Descent. Current cost function is  29.456784173020164
# Running Gradient Descent. Current cost function is  29.45210177509097
# Running Gradient Descent. Current cost function is  29.447484719634264
# Running Gradient Descent. Current cost function is  29.442932319409156
# Running Gradient Descent. Current cost function is  29.43844388688331
# Running Gradient Descent. Current cost function is  29.434018734485434
# Running Gradient Descent. Current cost function is  29.429656174852322
# Running Gradient Descent. Current cost function is  29.42535552107032
# Running Gradient Descent. Current cost function is  29.421116086911162
# Running Gradient Descent. Current cost function is  29.416937187062093
# Running Gradient Descent. Current cost function is  29.412818137350225
# Running Gradient Descent. Current cost function is  29.40875825496108
# Running Gradient Descent. Current cost function is  29.40475685865126
# Running Gradient Descent. Current cost function is  29.400813268955257
# Running Gradient Descent. Current cost function is  29.39692680838629
# Running Gradient Descent. Current cost function is  29.393096801631263
# Running Gradient Descent. Current cost function is  29.38932257573976
# Running Gradient Descent. Current cost function is  29.385603460307102
# Running Gradient Descent. Current cost function is  29.38193878765146
# Running Gradient Descent. Current cost function is  29.37832789298507
# Running Gradient Descent. Current cost function is  29.37477011457953
# Running Gradient Descent. Current cost function is  29.371264793925242
# Running Gradient Descent. Current cost function is  29.367811275885007
# Running Gradient Descent. Current cost function is  29.36440890884183
# Running Gradient Descent. Current cost function is  29.361057044840965
# Running Gradient Descent. Current cost function is  29.35775503972628
# Running Gradient Descent. Current cost function is  29.354502253270944
# Running Gradient Descent. Current cost function is  29.351298049302574
# Running Gradient Descent. Current cost function is  29.34814179582282
# Running Gradient Descent. Current cost function is  29.345032865121535
# Running Gradient Descent. Current cost function is  29.341970633885545
# Running Gradient Descent. Current cost function is  29.338954483302135
# Running Gradient Descent. Current cost function is  29.335983799157326
# Running Gradient Descent. Current cost function is  29.333057971928977
# Running Gradient Descent. Current cost function is  29.330176396874872
# Running Gradient Descent. Current cost function is  29.327338474115855
# Running Gradient Descent. Current cost function is  29.324543608714063
# Running Gradient Descent. Current cost function is  29.321791210746397
# Running Gradient Descent. Current cost function is  29.31908069537333
# Running Gradient Descent. Current cost function is  29.31641148290311
# Running Gradient Descent. Current cost function is  29.313782998851476
# Running Gradient Descent. Current cost function is  29.311194673997004
# Running Gradient Descent. Current cost function is  29.30864594443217
# Running Gradient Descent. Current cost function is  29.306136251610187
# Running Gradient Descent. Current cost function is  29.30366504238784
# Running Gradient Descent. Current cost function is  29.301231769064255
# Running Gradient Descent. Current cost function is  29.298835889415855
# Running Gradient Descent. Current cost function is  29.296476866727506
# Running Gradient Descent. Current cost function is  29.294154169820022
# Running Gradient Descent. Current cost function is  29.29186727307407
# Running Gradient Descent. Current cost function is  29.289615656450657
# Running Gradient Descent. Current cost function is  29.287398805508197
# Running Gradient Descent. Current cost function is  29.28521621141638
# Running Gradient Descent. Current cost function is  29.28306737096682
# Running Gradient Descent. Current cost function is  29.280951786580708
# Running Gradient Descent. Current cost function is  29.278868966313457
# Running Gradient Descent. Current cost function is  29.2768184238565
# Running Gradient Descent. Current cost function is  29.274799678536358
# Running Gradient Descent. Current cost function is  29.272812255310967
# Running Gradient Descent. Current cost function is  29.270855684763536
# Running Gradient Descent. Current cost function is  29.26892950309383
# Running Gradient Descent. Current cost function is  29.267033252107133
# Running Gradient Descent. Current cost function is  29.26516647920089
# Running Gradient Descent. Current cost function is  29.26332873734916
# Running Gradient Descent. Current cost function is  29.261519585084937
# Running Gradient Descent. Current cost function is  29.259738586480456
# Running Gradient Descent. Current cost function is  29.25798531112555
# Running Gradient Descent. Current cost function is  29.256259334104165
# Running Gradient Descent. Current cost function is  29.254560235969052
# Running Gradient Descent. Current cost function is  29.252887602714818
# Running Gradient Descent. Current cost function is  29.251241025749312
# Running Gradient Descent. Current cost function is  29.249620101863503
# Running Gradient Descent. Current cost function is  29.248024433199863
# Running Gradient Descent. Current cost function is  29.246453627219374
# Running Gradient Descent. Current cost function is  29.24490729666721
# Running Gradient Descent. Current cost function is  29.24338505953715
# Running Gradient Descent. Current cost function is  29.241886539034837
# Running Gradient Descent. Current cost function is  29.24041136353989
# Running Gradient Descent. Current cost function is  29.23895916656698
# Running Gradient Descent. Current cost function is  29.237529586725895
# Running Gradient Descent. Current cost function is  29.236122267680713
# Running Gradient Descent. Current cost function is  29.234736858108064
# Running Gradient Descent. Current cost function is  29.233373011654596
# Running Gradient Descent. Current cost function is  29.232030386893687
# Running Gradient Descent. Current cost function is  29.230708647281457
# Running Gradient Descent. Current cost function is  29.22940746111211
# Running Gradient Descent. Current cost function is  29.22812650147271
# Running Gradient Descent. Current cost function is  29.226865446197362
# Running Gradient Descent. Current cost function is  29.225623977820952
# Running Gradient Descent. Current cost function is  29.224401783532365
# Running Gradient Descent. Current cost function is  29.223198555127333
# Running Gradient Descent. Current cost function is  29.22201398896092
# Running Gradient Descent. Current cost function is  29.220847785899643
# Running Gradient Descent. Current cost function is  29.219699651273338
# Running Gradient Descent. Current cost function is  29.21856929482677
# Running Gradient Descent. Current cost function is  29.217456430671028
# Running Gradient Descent. Current cost function is  29.216360777234748
# Running Gradient Descent. Current cost function is  29.215282057215195
# Running Gradient Descent. Current cost function is  29.21421999752924
# Running Gradient Descent. Current cost function is  29.21317432926426
# Running Gradient Descent. Current cost function is  29.212144787628986
# Running Gradient Descent. Current cost function is  29.211131111904344
# Running Gradient Descent. Current cost function is  29.210133045394308
# Running Gradient Descent. Current cost function is  29.209150335376794
# Running Gradient Descent. Current cost function is  29.2081827330546
# Running Gradient Descent. Current cost function is  29.207229993506463
# Running Gradient Descent. Current cost function is  29.206291875638215
# Running Gradient Descent. Current cost function is  29.205368142134063
# Running Gradient Descent. Current cost function is  29.204458559408053
# Running Gradient Descent. Current cost function is  29.203562897555685
# Running Gradient Descent. Current cost function is  29.202680930305746
# Running Gradient Descent. Current cost function is  29.20181243497233
# Running Gradient Descent. Current cost function is  29.200957192407124
# Running Gradient Descent. Current cost function is  29.200114986951913
# Running Gradient Descent. Current cost function is  29.199285606391367
# Running Gradient Descent. Current cost function is  29.19846884190611
# Running Gradient Descent. Current cost function is  29.197664488026057
# Running Gradient Descent. Current cost function is  29.196872342584086
# Running Gradient Descent. Current cost function is  29.19609220667002
# Running Gradient Descent. Current cost function is  29.195323884584937
# Running Gradient Descent. Current cost function is  29.19456718379581
# Running Gradient Descent. Current cost function is  29.193821914890535
# Running Gradient Descent. Current cost function is  29.19308789153326
# Running Gradient Descent. Current cost function is  29.192364930420165
# Running Gradient Descent. Current cost function is  29.191652851235542
# Running Gradient Descent. Current cost function is  29.190951476608312
# Running Gradient Descent. Current cost function is  29.19026063206892
# Running Gradient Descent. Current cost function is  29.189580146006616
# Running Gradient Descent. Current cost function is  29.18890984962718
# Running Gradient Descent. Current cost function is  29.188249576911012
# Running Gradient Descent. Current cost function is  29.187599164571683
# Running Gradient Descent. Current cost function is  29.186958452014863
# Running Gradient Descent. Current cost function is  29.186327281297714
# Running Gradient Descent. Current cost function is  29.185705497088694
# Running Gradient Descent. Current cost function is  29.185092946627794
# Running Gradient Descent. Current cost function is  29.184489479687194
# Running Gradient Descent. Current cost function is  29.183894948532405
# Running Gradient Descent. Current cost function is  29.18330920788379
# Running Gradient Descent. Current cost function is  29.18273211487857
# Running Gradient Descent. Current cost function is  29.182163529033243
# Running Gradient Descent. Current cost function is  29.181603312206484
# Running Gradient Descent. Current cost function is  29.181051328562436
# Running Gradient Descent. Current cost function is  29.180507444534495
# Running Gradient Descent. Current cost function is  29.17997152878951
# Running Gradient Descent. Current cost function is  29.179443452192437
# Running Gradient Descent. Current cost function is  29.17892308777144
# Running Gradient Descent. Current cost function is  29.17841031068343
# Running Gradient Descent. Current cost function is  29.177904998180036
# Running Gradient Descent. Current cost function is  29.17740702957405
# Running Gradient Descent. Current cost function is  29.176916286206257
# Running Gradient Descent. Current cost function is  29.176432651412778
# Running Gradient Descent. Current cost function is  29.175956010492765
# Running Gradient Descent. Current cost function is  29.175486250676606
# Running Gradient Descent. Current cost function is  29.1750232610945
# Running Gradient Descent. Current cost function is  29.17456693274551
# Running Gradient Descent. Current cost function is  29.174117158467016
# Running Gradient Descent. Current cost function is  29.1736738329046
# Running Gradient Descent. Current cost function is  29.17323685248236
# Running Gradient Descent. Current cost function is  29.17280611537362
# Running Gradient Descent. Current cost function is  29.172381521472097
# Running Gradient Descent. Current cost function is  29.17196297236343
# Running Gradient Descent. Current cost function is  29.171550371297176
# Running Gradient Descent. Current cost function is  29.171143623159153
# Running Gradient Descent. Current cost function is  29.17074263444424
# Running Gradient Descent. Current cost function is  29.17034731322954
# Running Gradient Descent. Current cost function is  29.16995756914796
# Running Gradient Descent. Current cost function is  29.169573313362164
# Running Gradient Descent. Current cost function is  29.16919445853895
# Running Gradient Descent. Current cost function is  29.16882091882396
# Running Gradient Descent. Current cost function is  29.168452609816832
# Running Gradient Descent. Current cost function is  29.168089448546677
# Running Gradient Descent. Current cost function is  29.16773135344796
# Running Gradient Descent. Current cost function is  29.167378244336742
# Running Gradient Descent. Current cost function is  29.167030042387296
# Running Gradient Descent. Current cost function is  29.166686670109065
# Running Gradient Descent. Current cost function is  29.166348051323997
# Running Gradient Descent. Current cost function is  29.166014111144232
# Running Gradient Descent. Current cost function is  29.165684775950137
# Running Gradient Descent. Current cost function is  29.165359973368663
# Running Gradient Descent. Current cost function is  29.16503963225209
# Running Gradient Descent. Current cost function is  29.164723682657083
# Running Gradient Descent. Current cost function is  29.164412055824066
# Running Gradient Descent. Current cost function is  29.16410468415696
# Running Gradient Descent. Current cost function is  29.16380150120322
# Running Gradient Descent. Current cost function is  29.1635024416342
# Running Gradient Descent. Current cost function is  29.163207441225854
# Running Gradient Descent. Current cost function is  29.162916436839716
# Running Gradient Descent. Current cost function is  29.162629366404207
# Running Gradient Descent. Current cost function is  29.162346168896267
# Running Gradient Descent. Current cost function is  29.162066784323237
# Running Gradient Descent. Current cost function is  29.16179115370509
# Running Gradient Descent. Current cost function is  29.161519219056924
# Running Gradient Descent. Current cost function is  29.161250923371757
# Running Gradient Descent. Current cost function is  29.160986210603593
# Running Gradient Descent. Current cost function is  29.16072502565079
# Running Gradient Descent. Current cost function is  29.160467314339684
# Running Gradient Descent. Current cost function is  29.16021302340849
# Running Gradient Descent. Current cost function is  29.159962100491498
# Running Gradient Descent. Current cost function is  29.15971449410348
# Running Gradient Descent. Current cost function is  29.159470153624426
# Running Gradient Descent. Current cost function is  29.159229029284475
# Running Gradient Descent. Current cost function is  29.158991072149142
# Running Gradient Descent. Current cost function is  29.158756234104775
# Running Gradient Descent. Current cost function is  29.158524467844263
# Running Gradient Descent. Current cost function is  29.15829572685299
# Running Gradient Descent. Current cost function is  29.158069965395025
# Running Gradient Descent. Current cost function is  29.157847138499548
# Running Gradient Descent. Current cost function is  29.157627201947495
# Running Gradient Descent. Current cost function is  29.157410112258468
# Running Gradient Descent. Current cost function is  29.157195826677818
# Running Gradient Descent. Current cost function is  29.156984303164002
# Running Gradient Descent. Current cost function is  29.156775500376114
# Running Gradient Descent. Current cost function is  29.15656937766165
# Running Gradient Descent. Current cost function is  29.156365895044495
# Running Gradient Descent. Current cost function is  29.15616501321309
# Running Gradient Descent. Current cost function is  29.155966693508834
# Running Gradient Descent. Current cost function is  29.155770897914664
# Running Gradient Descent. Current cost function is  29.155577589043837
# Running Gradient Descent. Current cost function is  29.155386730128924
# Running Gradient Descent. Current cost function is  29.155198285010968
# Running Gradient Descent. Current cost function is  29.15501221812886
# Running Gradient Descent. Current cost function is  29.154828494508877
# Running Gradient Descent. Current cost function is  29.154647079754408
# Running Gradient Descent. Current cost function is  29.15446794003588
# Running Gradient Descent. Current cost function is  29.15429104208082
# Running Gradient Descent. Current cost function is  29.15411635316415
# Running Gradient Descent. Current cost function is  29.153943841098567
# Running Gradient Descent. Current cost function is  29.153773474225193
# Running Gradient Descent. Current cost function is  29.15360522140431
# Running Gradient Descent. Current cost function is  29.153439052006288
# Running Gradient Descent. Current cost function is  29.153274935902687
# Running Gradient Descent. Current cost function is  29.15311284345748
# Running Gradient Descent. Current cost function is  29.152952745518476
# Running Gradient Descent. Current cost function is  29.152794613408844
# Running Gradient Descent. Current cost function is  29.15263841891883
# Running Gradient Descent. Current cost function is  29.1524841342976
# Running Gradient Descent. Current cost function is  29.152331732245226
# Running Gradient Descent. Current cost function is  29.152181185904826
# Running Gradient Descent. Current cost function is  29.15203246885483
# Running Gradient Descent. Current cost function is  29.1518855551014
# Running Gradient Descent. Current cost function is  29.151740419070958
# Running Gradient Descent. Current cost function is  29.151597035602876
# Running Gradient Descent. Current cost function is  29.151455379942277
# Running Gradient Descent. Current cost function is  29.151315427732982
# Running Gradient Descent. Current cost function is  29.151177155010544
# Running Gradient Descent. Current cost function is  29.151040538195467
# Running Gradient Descent. Current cost function is  29.150905554086485
# Running Gradient Descent. Current cost function is  29.150772179854002
# Running Gradient Descent. Current cost function is  29.150640393033626
# Running Gradient Descent. Current cost function is  29.150510171519837
# Running Gradient Descent. Current cost function is  29.150381493559745
# Running Gradient Descent. Current cost function is  29.150254337746983
# Running Gradient Descent. Current cost function is  29.1501286830157
# Running Gradient Descent. Current cost function is  29.150004508634655
# Running Gradient Descent. Current cost function is  29.149881794201413
# Running Gradient Descent. Current cost function is  29.149760519636676
# Running Gradient Descent. Current cost function is  29.149640665178673
# Running Gradient Descent. Current cost function is  29.14952221137768
# Running Gradient Descent. Current cost function is  29.149405139090632
# Running Gradient Descent. Current cost function is  29.14928942947581
# Running Gradient Descent. Current cost function is  29.149175063987673
# Running Gradient Descent. Current cost function is  29.149062024371716
# Running Gradient Descent. Current cost function is  29.14895029265948
# Running Gradient Descent. Current cost function is  29.14883985116362
# Running Gradient Descent. Current cost function is  29.14873068247305
# Running Gradient Descent. Current cost function is  29.148622769448238
# Running Gradient Descent. Current cost function is  29.148516095216486
# Running Gradient Descent. Current cost function is  29.148410643167384
# Running Gradient Descent. Current cost function is  29.148306396948307
# Running Gradient Descent. Current cost function is  29.148203340459983
# Running Gradient Descent. Current cost function is  29.14810145785216
# Running Gradient Descent. Current cost function is  29.14800073351936
# Running Gradient Descent. Current cost function is  29.14790115209667
# Running Gradient Descent. Current cost function is  29.14780269845564
# Running Gradient Descent. Current cost function is  29.147705357700254
# Running Gradient Descent. Current cost function is  29.147609115162965
# Running Gradient Descent. Current cost function is  29.147513956400793
# Running Gradient Descent. Current cost function is  29.147419867191513
# Running Gradient Descent. Current cost function is  29.14732683352989
# Running Gradient Descent. Current cost function is  29.147234841624005
# Running Gradient Descent. Current cost function is  29.147143877891622
# Running Gradient Descent. Current cost function is  29.14705392895664
# Running Gradient Descent. Current cost function is  29.146964981645603
# Running Gradient Descent. Current cost function is  29.14687702298425
# Running Gradient Descent. Current cost function is  29.14679004019418
# Running Gradient Descent. Current cost function is  29.146704020689516
# Running Gradient Descent. Current cost function is  29.14661895207367
# Running Gradient Descent. Current cost function is  29.14653482213615
# Running Gradient Descent. Current cost function is  29.146451618849426
# Running Gradient Descent. Current cost function is  29.146369330365854
# Running Gradient Descent. Current cost function is  29.14628794501465
# Running Gradient Descent. Current cost function is  29.146207451298928
# Running Gradient Descent. Current cost function is  29.146127837892784
# Running Gradient Descent. Current cost function is  29.146049093638428
# Running Gradient Descent. Current cost function is  29.145971207543372
# Running Gradient Descent. Current cost function is  29.145894168777684
# Running Gradient Descent. Current cost function is  29.14581796667125
# Running Gradient Descent. Current cost function is  29.145742590711126
# Running Gradient Descent. Current cost function is  29.145668030538936
# Running Gradient Descent. Current cost function is  29.145594275948266
# Running Gradient Descent. Current cost function is  29.14552131688217
# Running Gradient Descent. Current cost function is  29.145449143430685
# Running Gradient Descent. Current cost function is  29.14537774582839
# Running Gradient Descent. Current cost function is  29.145307114452017
# Running Gradient Descent. Current cost function is  29.145237239818105
# Running Gradient Descent. Current cost function is  29.14516811258069
# Running Gradient Descent. Current cost function is  29.145099723529047
# Running Gradient Descent. Current cost function is  29.14503206358545
# Running Gradient Descent. Current cost function is  29.144965123803004
# Running Gradient Descent. Current cost function is  29.14489889536348
# Running Gradient Descent. Current cost function is  29.144833369575213
# Running Gradient Descent. Current cost function is  29.14476853787104
# Running Gradient Descent. Current cost function is  29.144704391806258
# Running Gradient Descent. Current cost function is  29.144640923056606
# Running Gradient Descent. Current cost function is  29.144578123416338
# Running Gradient Descent. Current cost function is  29.144515984796268
# Running Gradient Descent. Current cost function is  29.144454499221876
# Running Gradient Descent. Current cost function is  29.14439365883147
# Running Gradient Descent. Current cost function is  29.14433345587432
# Running Gradient Descent. Current cost function is  29.1442738827089
# Running Gradient Descent. Current cost function is  29.144214931801102
# Running Gradient Descent. Current cost function is  29.144156595722503
# Running Gradient Descent. Current cost function is  29.144098867148664
# Running Gradient Descent. Current cost function is  29.144041738857474
# Running Gradient Descent. Current cost function is  29.14398520372748
# Running Gradient Descent. Current cost function is  29.143929254736282
# Running Gradient Descent. Current cost function is  29.143873884958964
# Running Gradient Descent. Current cost function is  29.14381908756651
# Running Gradient Descent. Current cost function is  29.143764855824287
# Running Gradient Descent. Current cost function is  29.143711183090538
# Running Gradient Descent. Current cost function is  29.143658062814907
# Running Gradient Descent. Current cost function is  29.143605488536984
# Running Gradient Descent. Current cost function is  29.143553453884877
# Running Gradient Descent. Current cost function is  29.143501952573807
# Running Gradient Descent. Current cost function is  29.143450978404747
# Running Gradient Descent. Current cost function is  29.143400525263054
# Running Gradient Descent. Current cost function is  29.143350587117137
# Running Gradient Descent. Current cost function is  29.14330115801716
# Running Gradient Descent. Current cost function is  29.14325223209376
# Running Gradient Descent. Current cost function is  29.143203803556776
# Running Gradient Descent. Current cost function is  29.14315586669401
# Running Gradient Descent. Current cost function is  29.143108415870017
# Running Gradient Descent. Current cost function is  29.143061445524904
# Running Gradient Descent. Current cost function is  29.14301495017315
# Running Gradient Descent. Current cost function is  29.142968924402457
# Running Gradient Descent. Current cost function is  29.142923362872608
# Running Gradient Descent. Current cost function is  29.14287826031435
# Running Gradient Descent. Current cost function is  29.14283361152831
# Running Gradient Descent. Current cost function is  29.142789411383895
# Running Gradient Descent. Current cost function is  29.14274565481825
# Running Gradient Descent. Current cost function is  29.142702336835207
# Running Gradient Descent. Current cost function is  29.14265945250427
# Running Gradient Descent. Current cost function is  29.142616996959596
# Running Gradient Descent. Current cost function is  29.14257496539902
# Running Gradient Descent. Current cost function is  29.14253335308308
# Running Gradient Descent. Current cost function is  29.14249215533405
# Running Gradient Descent. Current cost function is  29.14245136753501
# Running Gradient Descent. Current cost function is  29.142410985128933
# Running Gradient Descent. Current cost function is  29.142371003617757
# Running Gradient Descent. Current cost function is  29.14233141856151
# Running Gradient Descent. Current cost function is  29.14229222557742
# Running Gradient Descent. Current cost function is  29.142253420339074
# Running Gradient Descent. Current cost function is  29.14221499857554
# Running Gradient Descent. Current cost function is  29.14217695607056
# Running Gradient Descent. Current cost function is  29.142139288661728
# Running Gradient Descent. Current cost function is  29.14210199223967
# Running Gradient Descent. Current cost function is  29.142065062747264
# Running Gradient Descent. Current cost function is  29.142028496178867
# Running Gradient Descent. Current cost function is  29.141992288579537
# Running Gradient Descent. Current cost function is  29.141956436044293
# Running Gradient Descent. Current cost function is  29.141920934717362
# Running Gradient Descent. Current cost function is  29.141885780791473
# Running Gradient Descent. Current cost function is  29.14185097050711
# Running Gradient Descent. Current cost function is  29.141816500151855
# Running Gradient Descent. Current cost function is  29.14178236605964
# Running Gradient Descent. Current cost function is  29.141748564610126
# Running Gradient Descent. Current cost function is  29.14171509222799
# Running Gradient Descent. Current cost function is  29.141681945382285
# Running Gradient Descent. Current cost function is  29.141649120585797
# Running Gradient Descent. Current cost function is  29.141616614394405
# Running Gradient Descent. Current cost function is  29.14158442340646
# Running Gradient Descent. Current cost function is  29.14155254426216
# Running Gradient Descent. Current cost function is  29.141520973642955
# Running Gradient Descent. Current cost function is  29.141489708270953
# Running Gradient Descent. Current cost function is  29.141458744908327
# Running Gradient Descent. Current cost function is  29.14142808035675
# Running Gradient Descent. Current cost function is  29.141397711456822
# Running Gradient Descent. Current cost function is  29.14136763508751
# Running Gradient Descent. Current cost function is  29.141337848165616
# Running Gradient Descent. Current cost function is  29.14130834764523
# Running Gradient Descent. Current cost function is  29.141279130517187
# Running Gradient Descent. Current cost function is  29.14125019380857
# Running Gradient Descent. Current cost function is  29.141221534582186
# Running Gradient Descent. Current cost function is  29.141193149936054
# Running Gradient Descent. Current cost function is  29.141165037002928
# Running Gradient Descent. Current cost function is  29.14113719294979
# Running Gradient Descent. Current cost function is  29.141109614977385
# Running Gradient Descent. Current cost function is  29.141082300319734
# Running Gradient Descent. Current cost function is  29.14105524624368
# Running Gradient Descent. Current cost function is  29.141028450048438
# Running Gradient Descent. Current cost function is  29.14100190906512
# Running Gradient Descent. Current cost function is  29.14097562065632
# Running Gradient Descent. Current cost function is  29.140949582215658
# Running Gradient Descent. Current cost function is  29.140923791167364
# Running Gradient Descent. Current cost function is  29.140898244965854
# Running Gradient Descent. Current cost function is  29.140872941095306
# Running Gradient Descent. Current cost function is  29.14084787706927
# Running Gradient Descent. Current cost function is  29.140823050430242
# Running Gradient Descent. Current cost function is  29.14079845874929
# Running Gradient Descent. Current cost function is  29.140774099625656
# Running Gradient Descent. Current cost function is  29.140749970686365
# Running Gradient Descent. Current cost function is  29.140726069585863
# Running Gradient Descent. Current cost function is  29.140702394005636
# Running Gradient Descent. Current cost function is  29.140678941653853
# Running Gradient Descent. Current cost function is  29.14065571026499
# Running Gradient Descent. Current cost function is  29.1406326975995
# Running Gradient Descent. Current cost function is  29.14060990144344
# Running Gradient Descent. Current cost function is  29.140587319608148
# Running Gradient Descent. Current cost function is  29.14056494992989
# Running Gradient Descent. Current cost function is  29.14054279026954
# Running Gradient Descent. Current cost function is  29.140520838512245
# Running Gradient Descent. Current cost function is  29.140499092567108
# Running Gradient Descent. Current cost function is  29.140477550366867
# Running Gradient Descent. Current cost function is  29.140456209867583
# Running Gradient Descent. Current cost function is  29.140435069048333
# Running Gradient Descent. Current cost function is  29.140414125910908
# Running Gradient Descent. Current cost function is  29.14039337847952
# Running Gradient Descent. Current cost function is  29.140372824800497
# Running Gradient Descent. Current cost function is  29.140352462942
# Running Gradient Descent. Current cost function is  29.140332290993747
# Running Gradient Descent. Current cost function is  29.14031230706672
# Running Gradient Descent. Current cost function is  29.14029250929288
# Running Gradient Descent. Current cost function is  29.140272895824936
# Running Gradient Descent. Current cost function is  29.14025346483603
# Running Gradient Descent. Current cost function is  29.140234214519495
# Running Gradient Descent. Current cost function is  29.140215143088604
# Running Gradient Descent. Current cost function is  29.140196248776295
# Running Gradient Descent. Current cost function is  29.14017752983493
# Running Gradient Descent. Current cost function is  29.140158984536047
# Running Gradient Descent. Current cost function is  29.140140611170114
# Running Gradient Descent. Current cost function is  29.140122408046285
# Running Gradient Descent. Current cost function is  29.140104373492168
# Running Gradient Descent. Current cost function is  29.140086505853592
# Running Gradient Descent. Current cost function is  29.140068803494366
# Running Gradient Descent. Current cost function is  29.140051264796064
# Running Gradient Descent. Current cost function is  29.140033888157802
# Running Gradient Descent. Current cost function is  29.140016671996012
# Running Gradient Descent. Current cost function is  29.13999961474422
# Running Gradient Descent. Current cost function is  29.13998271485285
# Running Gradient Descent. Current cost function is  29.139965970788992
# ...
# Running Gradient Descent. Current cost function is  29.13890103095345
# Running Gradient Descent. Current cost function is  29.138894098484098
# Running Gradient Descent. Current cost function is  29.138887227919316
# Running Gradient Descent. Current cost function is  29.13888041869494
# Running Gradient Descent. Current cost function is  29.138873670252167
# Running Gradient Descent. Current cost function is  29.13886698203751
# Running Gradient Descent. Current cost function is  29.138860353502736
# Running Gradient Descent. Current cost function is  29.138853784104807
# Running Gradient Descent. Current cost function is  29.138847273305842
# Running Gradient Descent. Current cost function is  29.138840820573044
# Running Gradient Descent. Current cost function is  29.13883442537867
# Running Gradient Descent. Current cost function is  29.138828087199954
# Running Gradient Descent. Current cost function is  29.13882180551908
# Running Gradient Descent. Current cost function is  29.138815579823117
# Running Gradient Descent. Current cost function is  29.13880940960398
# Running Gradient Descent. Current cost function is  29.138803294358368
# Running Gradient Descent. Current cost function is  29.138797233587727
# Running Gradient Descent. Current cost function is  29.13879122679819
# Running Gradient Descent. Current cost function is  29.13878527350054
# Running Gradient Descent. Current cost function is  29.13877937321017
# Running Gradient Descent. Current cost function is  29.138773525447007
# Running Gradient Descent. Current cost function is  29.138767729735495
# Running Gradient Descent. Current cost function is  29.138761985604546
# Running Gradient Descent. Current cost function is  29.138756292587473
# Running Gradient Descent. Current cost function is  29.138750650221976
# Running Gradient Descent. Current cost function is  29.138745058050077
# Running Gradient Descent. Current cost function is  29.138739515618084
# Running Gradient Descent. Current cost function is  29.138734022476545
# Running Gradient Descent. Current cost function is  29.13872857818021
# Running Gradient Descent. Current cost function is  29.138723182287993
# Running Gradient Descent. Current cost function is  29.138717834362915
# Running Gradient Descent. Current cost function is  29.138712533972075
# Running Gradient Descent. Current cost function is  29.138707280686607
# Running Gradient Descent. Current cost function is  29.138702074081646
# Running Gradient Descent. Current cost function is  29.138696913736272
# Running Gradient Descent. Current cost function is  29.13869179923349
# Running Gradient Descent. Current cost function is  29.138686730160178
# Running Gradient Descent. Current cost function is  29.13868170610705
# Running Gradient Descent. Current cost function is  29.138676726668628
# Running Gradient Descent. Current cost function is  29.13867179144319
# Running Gradient Descent. Current cost function is  29.138666900032746
# Running Gradient Descent. Current cost function is  29.138662052042992
# Running Gradient Descent. Current cost function is  29.138657247083284
# Running Gradient Descent. Current cost function is  29.138652484766585
# Running Gradient Descent. Current cost function is  29.138647764709447
# Running Gradient Descent. Current cost function is  29.138643086531967
# Running Gradient Descent. Current cost function is  29.138638449857755
# Running Gradient Descent. Current cost function is  29.1386338543139
# Running Gradient Descent. Current cost function is  29.13862929953093
# Running Gradient Descent. Current cost function is  29.138624785142785
# Running Gradient Descent. Current cost function is  29.138620310786784
# Running Gradient Descent. Current cost function is  29.138615876103593
# Running Gradient Descent. Current cost function is  29.138611480737183
# Running Gradient Descent. Current cost function is  29.138607124334804
# Running Gradient Descent. Current cost function is  29.13860280654696
# Running Gradient Descent. Current cost function is  29.138598527027362
# Running Gradient Descent. Current cost function is  29.138594285432916
# Running Gradient Descent. Current cost function is  29.138590081423676
# Running Gradient Descent. Current cost function is  29.138585914662816
# Running Gradient Descent. Current cost function is  29.138581784816612
# Running Gradient Descent. Current cost function is  29.138577691554396
# Running Gradient Descent. Current cost function is  29.13857363454854
# Running Gradient Descent. Current cost function is  29.13856961347441
# Running Gradient Descent. Current cost function is  29.138565628010358
# Running Gradient Descent. Current cost function is  29.138561677837682
# Running Gradient Descent. Current cost function is  29.138557762640595
# Running Gradient Descent. Current cost function is  29.138553882106198
# Running Gradient Descent. Current cost function is  29.13855003592446
# Running Gradient Descent. Current cost function is  29.13854622378819
# Running Gradient Descent. Current cost function is  29.138542445392993
# Running Gradient Descent. Current cost function is  29.138538700437262
# Running Gradient Descent. Current cost function is  29.13853498862215
# Running Gradient Descent. Current cost function is  29.138531309651526
# Running Gradient Descent. Current cost function is  29.138527663231976
# Running Gradient Descent. Current cost function is  29.13852404907275
# Running Gradient Descent. Current cost function is  29.13852046688576
# Running Gradient Descent. Current cost function is  29.138516916385527
# Running Gradient Descent. Current cost function is  29.1385133972892
# Running Gradient Descent. Current cost function is  29.138509909316475
# Running Gradient Descent. Current cost function is  29.13850645218962
# Running Gradient Descent. Current cost function is  29.138503025633426
# Running Gradient Descent. Current cost function is  29.138499629375186
# Running Gradient Descent. Current cost function is  29.138496263144667
# Running Gradient Descent. Current cost function is  29.1384929266741
# Running Gradient Descent. Current cost function is  29.13848961969815
# Running Gradient Descent. Current cost function is  29.138486341953886
# Running Gradient Descent. Current cost function is  29.13848309318077
# Running Gradient Descent. Current cost function is  29.138479873120627
# Running Gradient Descent. Current cost function is  29.138476681517623
# Running Gradient Descent. Current cost function is  29.138473518118246
# Running Gradient Descent. Current cost function is  29.138470382671283
# Running Gradient Descent. Current cost function is  29.138467274927795
# Running Gradient Descent. Current cost function is  29.1384641946411
# Running Gradient Descent. Current cost function is  29.138461141566758
# Running Gradient Descent. Current cost function is  29.138458115462527
# Running Gradient Descent. Current cost function is  29.138455116088373
# Running Gradient Descent. Current cost function is  29.138452143206422
# Running Gradient Descent. Current cost function is  29.13844919658096
# Running Gradient Descent. Current cost function is  29.138446275978403
# Running Gradient Descent. Current cost function is  29.138443381167274
# Running Gradient Descent. Current cost function is  29.138440511918194
# Running Gradient Descent. Current cost function is  29.138437668003853
# Running Gradient Descent. Current cost function is  29.13843484919899
# Running Gradient Descent. Current cost function is  29.13843205528039
# Running Gradient Descent. Current cost function is  29.138429286026835
# Running Gradient Descent. Current cost function is  29.13842654121912
# Running Gradient Descent. Current cost function is  29.138423820640007
# Running Gradient Descent. Current cost function is  29.138421124074224
# Running Gradient Descent. Current cost function is  29.138418451308432
# Running Gradient Descent. Current cost function is  29.13841580213122
# Running Gradient Descent. Current cost function is  29.13841317633308
# Running Gradient Descent. Current cost function is  29.1384105737064
# Running Gradient Descent. Current cost function is  29.138407994045416
# Running Gradient Descent. Current cost function is  29.138405437146236
# Running Gradient Descent. Current cost function is  29.1384029028068
# Running Gradient Descent. Current cost function is  29.138400390826856
# Running Gradient Descent. Current cost function is  29.13839790100797
# Running Gradient Descent. Current cost function is  29.138395433153473
# Running Gradient Descent. Current cost function is  29.138392987068478
# Running Gradient Descent. Current cost function is  29.13839056255985
# Running Gradient Descent. Current cost function is  29.13838815943618
# Running Gradient Descent. Current cost function is  29.138385777507782
# Running Gradient Descent. Current cost function is  29.13838341658668
# Running Gradient Descent. Current cost function is  29.138381076486578
# Running Gradient Descent. Current cost function is  29.13837875702286
# Running Gradient Descent. Current cost function is  29.13837645801256
# Running Gradient Descent. Current cost function is  29.138374179274354
# Running Gradient Descent. Current cost function is  29.13837192062855
# Running Gradient Descent. Current cost function is  29.138369681897068
# Running Gradient Descent. Current cost function is  29.13836746290341
# Running Gradient Descent. Current cost function is  29.138365263472682
# Running Gradient Descent. Current cost function is  29.138363083431546
# Running Gradient Descent. Current cost function is  29.13836092260821
# Running Gradient Descent. Current cost function is  29.138358780832437
# Running Gradient Descent. Current cost function is  29.138356657935503
# Running Gradient Descent. Current cost function is  29.138354553750197
# Running Gradient Descent. Current cost function is  29.13835246811081
# Running Gradient Descent. Current cost function is  29.13835040085311
# Running Gradient Descent. Current cost function is  29.13834835181434
# Running Gradient Descent. Current cost function is  29.138346320833193
# Running Gradient Descent. Current cost function is  29.13834430774981
# Running Gradient Descent. Current cost function is  29.138342312405765
# Running Gradient Descent. Current cost function is  29.13834033464403
# Running Gradient Descent. Current cost function is  29.138338374309008
# Running Gradient Descent. Current cost function is  29.138336431246472
# Running Gradient Descent. Current cost function is  29.13833450530358
# Running Gradient Descent. Current cost function is  29.13833259632886
# Running Gradient Descent. Current cost function is  29.13833070417218
# Running Gradient Descent. Current cost function is  29.138328828684767
# Running Gradient Descent. Current cost function is  29.13832696971916
# Running Gradient Descent. Current cost function is  29.138325127129225
# Running Gradient Descent. Current cost function is  29.13832330077013
# Running Gradient Descent. Current cost function is  29.138321490498328
# Running Gradient Descent. Current cost function is  29.138319696171564
# Running Gradient Descent. Current cost function is  29.138317917648845
# Running Gradient Descent. Current cost function is  29.138316154790438
# Running Gradient Descent. Current cost function is  29.13831440745786
# Running Gradient Descent. Current cost function is  29.13831267551385
# Running Gradient Descent. Current cost function is  29.138310958822384
# Running Gradient Descent. Current cost function is  29.138309257248647
# Running Gradient Descent. Current cost function is  29.138307570659023
# Running Gradient Descent. Current cost function is  29.13830589892109
# Running Gradient Descent. Current cost function is  29.138304241903597
# Running Gradient Descent. Current cost function is  29.138302599476475
# Running Gradient Descent. Current cost function is  29.1383009715108
# Running Gradient Descent. Current cost function is  29.138299357878815
# Running Gradient Descent. Current cost function is  29.138297758453877
# Running Gradient Descent. Current cost function is  29.138296173110486
# Running Gradient Descent. Current cost function is  29.138294601724255
# Running Gradient Descent. Current cost function is  29.138293044171906
# Running Gradient Descent. Current cost function is  29.138291500331253
# Running Gradient Descent. Current cost function is  29.1382899700812
# Running Gradient Descent. Current cost function is  29.13828845330173
# Running Gradient Descent. Current cost function is  29.13828694987389
# Running Gradient Descent. Current cost function is  29.13828545967979
# Running Gradient Descent. Current cost function is  29.13828398260258
# Running Gradient Descent. Current cost function is  29.138282518526452
# Running Gradient Descent. Current cost function is  29.138281067336635
# Running Gradient Descent. Current cost function is  29.13827962891937
# Running Gradient Descent. Current cost function is  29.13827820316191
# Running Gradient Descent. Current cost function is  29.13827678995251
# Running Gradient Descent. Current cost function is  29.138275389180418
# Running Gradient Descent. Current cost function is  29.13827400073587
# Running Gradient Descent. Current cost function is  29.13827262451007
# Running Gradient Descent. Current cost function is  29.13827126039519
# Running Gradient Descent. Current cost function is  29.138269908284368
# Running Gradient Descent. Current cost function is  29.138268568071677
# Running Gradient Descent. Current cost function is  29.13826723965214
# Running Gradient Descent. Current cost function is  29.138265922921708
# Running Gradient Descent. Current cost function is  29.138264617777256
# Running Gradient Descent. Current cost function is  29.13826332411658
# Running Gradient Descent. Current cost function is  29.13826204183837
# Running Gradient Descent. Current cost function is  29.13826077084223
# Running Gradient Descent. Current cost function is  29.13825951102864
# Running Gradient Descent. Current cost function is  29.138258262298972
# Running Gradient Descent. Current cost function is  29.138257024555475
# Running Gradient Descent. Current cost function is  29.138255797701255
# Running Gradient Descent. Current cost function is  29.138254581640286
# Running Gradient Descent. Current cost function is  29.138253376277387
# Running Gradient Descent. Current cost function is  29.138252181518226
# Running Gradient Descent. Current cost function is  29.138250997269306
# Running Gradient Descent. Current cost function is  29.138249823437956
# Running Gradient Descent. Current cost function is  29.13824865993233
# Running Gradient Descent. Current cost function is  29.138247506661394
# Running Gradient Descent. Current cost function is  29.13824636353492
# Running Gradient Descent. Current cost function is  29.138245230463475
# Running Gradient Descent. Current cost function is  29.13824410735843
# Running Gradient Descent. Current cost function is  29.138242994131936
# Running Gradient Descent. Current cost function is  29.138241890696914
# Running Gradient Descent. Current cost function is  29.138240796967068
# Running Gradient Descent. Current cost function is  29.13823971285686
# Running Gradient Descent. Current cost function is  29.138238638281507
# Running Gradient Descent. Current cost function is  29.13823757315698
# Running Gradient Descent. Current cost function is  29.1382365174
# Running Gradient Descent. Current cost function is  29.138235470928013
# Running Gradient Descent. Current cost function is  29.138234433659207
# Running Gradient Descent. Current cost function is  29.138233405512484
# Running Gradient Descent. Current cost function is  29.13823238640747
# Running Gradient Descent. Current cost function is  29.138231376264503
# Running Gradient Descent. Current cost function is  29.138230375004625
# Running Gradient Descent. Current cost function is  29.138229382549568
# Running Gradient Descent. Current cost function is  29.138228398821774
# Running Gradient Descent. Current cost function is  29.13822742374435
# Running Gradient Descent. Current cost function is  29.138226457241103
# Running Gradient Descent. Current cost function is  29.1382254992365
# Running Gradient Descent. Current cost function is  29.138224549655686

# %%
# Now, lets see our trained weights
print('Our learned value of theta: ',theta.ravel())
# Out:
# Our learned value of theta:  [340397.96353532 108742.65627238  -5873.22993383]

# %% [markdown]
# Lets visualize how or error reduced during the iteration. This is the power of gradient descent.

# %%
plt.plot(cost_values)
plt.ylabel('Cost J')
plt.xlabel('Iterations');

# %% [markdown]
# Notice that at the `400th iteration`, the model doesnt really change anymore. You should actually stop the iteration at that time and save cost of processing

# %% [markdown]
# ## Predict
#
# Lets write a predict function that takes in the input features and produces an estimate price for the type of house desired

# %%
def predict(theta, mean, std):
    input_size = float(input("Input the size (square feet) of house you want: "))
    input_bedrooms = float(input("Input the number of bedrooms you desire: "))
    print("\nCalculating... ... ... ... ... ...\n")
    input_vec = np.array([[1, input_size, input_bedrooms]])
    
    input_norm = np.ones(input_vec.shape)
    input_norm.dtype = np.float
    
    input_norm[:, 1:] = np.divide((input_vec[:, 1:] - mean), std)
    
    price = input_norm @ theta
    print("For a house of size ", input_size, "sqft, with ", input_bedrooms, "rooms, \nThe price estimate is N", price[0][0])

# %%
predict(theta, mean, standard_deviation)
# Out:
# Input the size (square feet) of house you want: 1650
# Input the number of bedrooms you desire: 4
#
# Calculating... ... ... ... ... ...
#
# For a house of size  1650.0 sqft, with  4.0 rooms,
# The price estimate is N 285420.4649696114

# %% [markdown]
# ## Learning Rates

# %% [markdown]
# But what ius the effect of varying learning rates in the optimization of our weights?
# Below, we will plot the effect of different learning on the optimization of theta.
#
# Study the code for the next 5 mins...

# %%
# Choose some alpha value
alphas = [1,0,0.1,0.012]

def update_weight_r(h, theta, x, alpha):
    m = x[:,0].size
    theta = theta - alpha * (1/m * (x.T @ (h - y)))
    return theta

def cost_r(x):
    J = []
    theta = [[0],[0],[0]]
    iteration = 400
    for i in alphas:
        alpha = i
        m = x[:,0].size
        J_alpha = []
        for i in range(iteration):
            h = x @ theta
            theta = update_weight_r(h, theta, x, alpha)
            cost = (1/2*m) * np.sum(np.square(h - y))
            J_alpha.append(cost)
        # reset theta to zero
        theta = [[0],[0],[0]]
        J.append(J_alpha)
    return J

# %%
# Lets pass in the value of x into our function defined above 
cost_alpha = cost_r(x)

plt.figure()
plt.subplot(2,2,1)
plt.plot(cost_alpha[0])
plt.title('lr= 1')

plt.subplot(2,2,2)
plt.plot(cost_alpha[1])
plt.title('lr= 0')

plt.subplot(2,2,3)
plt.plot(cost_alpha[2])
plt.title('lr= 0.1')

plt.subplot(2,2,4)
plt.plot(cost_alpha[3])
plt.title('lr= 0.01')
# Out:
# Text(0.5, 1.0, 'lr= 0.01')

# %% [markdown]
# **Class Discussion:** What did you notice in this plots

# %% [markdown]
# ## Normal Equation (Analytical Method)

# %% [markdown]
# $$\theta = (X^TX)^{-1}X^T\vec{y}$$
# Using this formula does not require any feature scaling, and you will get an exact solution in one calculation: there is no \loop until convergence" like in gradient descent.
#
# Complete the code in normaleqn.py to use the formula above to calcu- late $\theta$. Remember that while you don't need to scale your features, we still need to add a column of 1's to the X matrix to have an intercept term

# %%
# lets define the formula in a function
def normalEqn(X,y):
    return np.dot((np.linalg.inv(np.dot(X.T,X))),np.dot(X.T,y))

# %%
# Lets pass in our inout values the have not been normalized
x_non_norm = np.concatenate((np.ones((x_data[:,0].size, 1)), x_data), axis=1) 

theta_analytical = normalEqn(x_non_norm, y)

# Display normal equation's result
print ('Theta computed from the normal equations:')
print (' %s \n' % theta_analytical)
# Out:
# Theta computed from the normal equations:
#  [[89597.9095428 ]
#  [  139.21067402]
#  [-8738.01911233]]

# %%
#Predict
def predict_analytical(theta):
    input_size = float(input("Input the size (square feet) of house you want: "))
    input_bedrooms = float(input("Input the number of bedrooms you desire: "))
    print("\nCalculating... ... ... ... ... ...\n")
    input_vec = np.array([[1, input_size, input_bedrooms]])
    
    
    price = input_vec @ theta
    print("For a house of size ", input_size, "sqft, with ", input_bedrooms, "rooms, \nThe price estimate is N", price[0][0])

# %%
predict_analytical(theta_analytical)
# Out:
# Input the size (square feet) of house you want: 1650
# Input the number of bedrooms you desire: 4
#
# Calculating... ... ... ... ... ...
#
# For a house of size  1650.0 sqft, with  4.0 rooms,
# The price estimate is N 284343.4452225697

# %% [markdown]
# ### Assignment:
#
# 1. Use `scikit-learn` to develop a linear regression model using the same dataset in this practice and compare result.
# 2. Explore the internet for an multivariant dataset and use this algorithim to train a linear regression model. Use `scikit-learn` too
#
# Assignment is due for submission on `05/04/2019`.
#
# Summission link will be posted on the `WhatsApp Class Group`
