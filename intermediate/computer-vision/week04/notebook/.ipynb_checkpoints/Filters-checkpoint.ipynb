# %% [markdown]
# # Filters

# %% [markdown]
# Filters are used to

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
test_image = cv2.imread("./teju.jpg")
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,10))
plt.imshow(test_image)

# %% [markdown]
# gaussian noise

# %%
# create a gaussian noise
sigma = 50
noise = np.random.randn(*test_image.shape)*sigma

# %%
# add noise to image
noise_image = test_image + noise

# %%
# noise image is a float (confirm this)
# images should be of type uint8 (for 8 bit images)
noise_image = np.array(noise_image, dtype=np.uint8)

# %%
# display noise image
plt.imshow(noise_image)

# %% [markdown]
# #### Filtering

# %%
## write a fuction that applies a kernel to an image
# using cv2.filter2D
def applykernel(image, kernel):
    
    output = cv2.filter2D(noise_image,-1,kernel)
    
    return output


## a function that displays an image
def display(img):
    plt.figure(figsize=(10,10))
    plt.imshow(img)

# %% [markdown]
# ### Averaging filter

# %% [markdown]
# when performing averaging, each pixel is replaced by an average of neighboring pixels

# %%
# TODO
# create a kernel and apply it to the test_image

averagingkernel = None
output = applykernel(test_image, averagingkernel)

# display output
display(output)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-124-7625dfd5ce03> in <module>
#       3
#       4 averagingkernel = None
# ----> 5 output = applykernel(test_image, averagingkernel)
#       6
#       7 # display output
#
# <ipython-input-123-47216fb77e3b> in applykernel(image, kernel)
#       3 def applykernel(image, kernel):
#       4
# ----> 5     output = cv2.filter2D(noise_image,-1,kernel)
#       6
#       7     return output
#
# error: OpenCV(4.1.1) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/filterengine.hpp:363: error: (-215:Assertion failed) anchor.inside(Rect(0, 0, ksize.width, ksize.height)) in function 'normalizeAnchor'

# %% [markdown]
# ### Gausian filter

# %%
# TODO
# create a kernel and apply it to the test_image

gaussiankernel = None
output = applykernel(test_image, gaussiankernel)

# display output
display(output)

# %% [markdown]
# salt and pepper noise

# %%
mask = (np.random.random(test_image.shape[:-1]) > 0.9)
noise =  mask \
        * np.random.random(test_image.shape[:-1])\
        *random.choice([0])
noise = np.expand_dims(noise, -1)
mask = 1-np.expand_dims(mask, -1)

noise_image = noise + mask*test_image

noise_image = np.array(noise_image, dtype=np.uint8)

# %%
display(noise_image)

# %% [markdown]
# ### median filter

# %%
median = cv2.medianBlur(noise_image,5)
display(median)

# %% [markdown]
# ### fun with filters

# %%
kernel = np.zeros((3,3), np.float32)
kernel[1,2] = 1
# kernel = np.ones((5,5),np.float32)/25

# %%
output = applykernel(test_image, kernel)
display(output)
